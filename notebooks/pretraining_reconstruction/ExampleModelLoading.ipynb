# %% [markdown]
# # Example Model Loading
#
# This notebook is an example for loading the pre-trained model. Given that this is just a test, you
# will only be able to load this model from Explore for now.

# %%
# !pip install pytorch-lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytorch-lightning in /home/aliewehr/.local/lib/python3.12/site-packages (2.6.5)
# Requirement already satisfied: torch>=2.1.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from pytorch-lightning) (2.13.0)
# Requirement already satisfied: tqdm>=4.57.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: PyYAML>5.4 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2025.3.0)
# Requirement already satisfied: torchmetrics>0.7.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from pytorch-lightning) (1.9.0)
# Requirement already satisfied: packaging>=23.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from pytorch-lightning) (24.2)
# Requirement already satisfied: typing-extensions>4.5.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from pytorch-lightning) (0.15.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.11.14)
# Requirement already satisfied: filelock in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (3.18.0)
# Requirement already satisfied: setuptools>=77.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch>=2.1.0->pytorch-lightning) (3.7.1)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.1.0->pytorch-lightning) (13.0.85)
# Requirement already satisfied: numpy>1.20.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torchmetrics>0.7.0->pytorch-lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.18.3)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.1.0->pytorch-lightning) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.10)

# %%
# !pip install lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lightning
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from lightning) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from lightning) (2.13.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from lightning) (1.9.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /home/aliewehr/.local/lib/python3.12/site-packages (from lightning) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (3.11.14)
# Requirement already satisfied: filelock in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (3.18.0)
# Requirement already satisfied: setuptools>=77.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /home/aliewehr/.local/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning) (3.7.1)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch<4.0,>=2.1.0->lightning) (13.0.85)
# Requirement already satisfied: numpy>1.20.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from torchmetrics<3.0,>0.7.0->lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.18.3)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/aliewehr/.local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch<4.0,>=2.1.0->lightning) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aliewehr/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /panfs/ccds02/app/modules/jupyter/lab/4.3.6/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (3.10)
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: lightning
#   WARNING: The script fabric is installed in '/home/aliewehr/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed lightning-2.6.5

# %%
import sys
print(sys.executable)
# Out:
# /panfs/ccds02/app/modules/anaconda/platform/x86_64/rhel/8.6/3-2022.05/envs/ilab-pytorch/bin/python

# %%
# !{sys.executable} -m pip install lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightning in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (2.6.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from lightning) (6.0)
# Requirement already satisfied: packaging<27.0,>=20.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from lightning) (21.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (0.15.2)
# Requirement already satisfied: fsspec[http]<2027.0,>=2022.5.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (2025.10.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from lightning) (4.64.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (2.8.0)
# Requirement already satisfied: pytorch-lightning in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (2.6.0)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (4.16.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from lightning) (1.8.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning) (3.8.3)
# Requirement already satisfied: setuptools in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (60.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from packaging<27.0,>=20.0->lightning) (3.0.9)
# Requirement already satisfied: jinja2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.5.8.93)
# Requirement already satisfied: filelock in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (3.19.1)
# Requirement already satisfied: triton==3.4.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (3.4.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.4.1)
# Requirement already satisfied: sympy>=1.13.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (1.14.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (2.27.3)
# Requirement already satisfied: networkx in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (2.6.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (12.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch<4.0,>=2.1.0->lightning) (0.7.1)
# Requirement already satisfied: importlib-metadata in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from triton==3.4.0->torch<4.0,>=2.1.0->lightning) (5.0.0)
# Requirement already satisfied: numpy>1.20.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torchmetrics<3.0,>0.7.0->lightning) (1.23.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (22.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from sympy>=1.13.3->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.1)
# Requirement already satisfied: idna>=2.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning) (3.4)
# Requirement already satisfied: zipp>=0.5 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch<4.0,>=2.1.0->lightning) (3.10.0)

# %%
# !{sys.executable} -m pip install yacs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yacs in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (0.1.8)
# Requirement already satisfied: PyYAML in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from yacs) (6.0)

# %%
# !{sys.executable} -m pip install timm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (1.0.28)
# Requirement already satisfied: torch in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from timm) (2.8.0)
# Requirement already satisfied: torchvision in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from timm) (0.14.0)
# Requirement already satisfied: huggingface_hub in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from timm) (1.8.0)
# Requirement already satisfied: pyyaml in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from timm) (6.0)
# Requirement already satisfied: safetensors in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from timm) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (1.5.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (4.16.0)
# Requirement already satisfied: typer in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (0.23.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (2025.10.0)
# Requirement already satisfied: filelock>=3.10.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (3.19.1)
# Requirement already satisfied: tqdm>=4.42.1 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from huggingface_hub->timm) (4.64.1)
# Requirement already satisfied: packaging>=20.9 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from huggingface_hub->timm) (0.28.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.5.8.93)
# Requirement already satisfied: sympy>=1.13.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (1.13.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (10.3.9.90)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (2.27.3)
# Requirement already satisfied: networkx in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torch->timm) (2.6.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: jinja2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torch->timm) (3.1.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.4.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: triton==3.4.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (3.4.0)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (11.7.3.90)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from torch->timm) (11.3.3.83)
# Requirement already satisfied: setuptools>=40.8.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from triton==3.4.0->torch->timm) (60.10.0)
# Requirement already satisfied: importlib-metadata in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from triton==3.4.0->torch->timm) (5.0.0)
# Requirement already satisfied: numpy in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: requests in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torchvision->timm) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from torchvision->timm) (9.2.0)
# Requirement already satisfied: idna in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (3.4)
# Requirement already satisfied: certifi in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (2025.8.3)
# Requirement already satisfied: anyio in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (3.6.2)
# Requirement already satisfied: httpcore==1.* in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm) (0.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from packaging>=20.9->huggingface_hub->timm) (3.0.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from jinja2->torch->timm) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from requests->torchvision->timm) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from requests->torchvision->timm) (2.1.1)
# Requirement already satisfied: click>=8.0.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from typer->huggingface_hub->timm) (8.1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from typer->huggingface_hub->timm) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from typer->huggingface_hub->timm) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from typer->huggingface_hub->timm) (0.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm) (2.13.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub->timm) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /panfs/ccds02/app/modules/jupyter/ilab/pytorch-kernel-current-20260416/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch->timm) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /panfs/ccds02/nobackup/people/aliewehr/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm) (0.1.2)

# %%
# !{sys.executable} -m pip install flash-attn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flash-attn
#   Downloading flash_attn-2.8.3.post1.tar.gz (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 39.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       /panfs/ccds02/nobackup/people/aliewehr/.nccstmp/pip-install-y9eab2_j/flash-attn_be91912ccd694cac9166944380f4bf4a/setup.py:106: UserWarning: flash_attn was requested, but nvcc was not found.  Are you sure your environment has nvcc available?  If you're installing within a container from https://hub.docker.com/r/pytorch/pytorch, only images whose names contain 'devel' will provide nvcc.
#         warnings.warn(
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/panfs/ccds02/nobackup/people/aliewehr/.nccstmp/pip-install-y9eab2_j/flash-attn_be91912ccd694cac9166944380f4bf4a/setup.py", line 227, in <module>
#           CUDAExtension(
#         File "/home/aliewehr/.local/lib/python3.9/site-packages/torch/utils/cpp_extension.py", line 1337, in CUDAExtension
#           library_dirs += library_paths(device_type="cuda")
#         File "/home/aliewehr/.local/lib/python3.9/site-packages/torch/utils/cpp_extension.py", line 1548, in library_paths
#           if (not os.path.exists(_join_cuda_home(lib_dir)) and
#         File "/home/aliewehr/.local/lib/python3.9/site-packages/torch/utils/cpp_extension.py", line 2982, in _join_cuda_home
#           raise OSError('CUDA_HOME environment variable is not set. '
#       OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#
#
#       torch.__version__  = 2.8.0+cu128
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import torch
print(torch.__version__)
# Out:
# 2.8.0+cu128

# %%
import sys

# sys.path.append('/explore/nobackup/people/jacaraba/development/satvision-pix4d')
sys.path.insert(0, '/home/aliewehr/satvision-pix4d')

import os
import torch
import logging
import argparse

import warnings

warnings.filterwarnings("ignore", message=".*cuda capability 7.0.*")

from lightning.pytorch import Trainer
from lightning.pytorch.loggers import MLFlowLogger
from lightning.pytorch.callbacks import ModelCheckpoint, LearningRateMonitor

from satvision_pix4d.configs.config import _C, _update_config_from_file
from satvision_pix4d.utils import get_strategy, get_distributed_train_batches
from satvision_pix4d.pipelines import PIPELINES, get_available_pipelines
from satvision_pix4d.datamodules import DATAMODULES, get_available_datamodules
# Out:
# /panfs/ccds02/app/modules/anaconda/platform/x86_64/rhel/8.6/3-2022.05/envs/ilab-pytorch/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [6], line 21
#      19 from satvision_pix4d.configs.config import _C, _update_config_from_file
#      20 from satvision_pix4d.utils import get_strategy, get_distributed_train_batches
# ---> 21 from satvision_pix4d.pipelines import PIPELINES, get_available_pipelines
#      22 from satvision_pix4d.datamodules import DATAMODULES, get_available_datamodules
#
# File ~/satvision-pix4d/satvision_pix4d/pipelines/__init__.py:1
# ----> 1 from satvision_pix4d.pipelines.satvision_pix4d_pretrain import SatVisionPix4DSatMAEPretrain
#       4 PIPELINES = {
#       5     'satvision_pix4d_satmae_pretrain': SatVisionPix4DSatMAEPretrain,
#       6 }
#       9 def get_available_pipelines():
#
# File ~/satvision-pix4d/satvision_pix4d/pipelines/satvision_pix4d_pretrain.py:8
#       5 import lightning.pytorch as pl
#       7 from satvision_pix4d.models.encoders.mae import build_satmae_model
# ----> 8 from satvision_pix4d.optimizers.build import build_optimizer
#      11 class SatVisionPix4DSatMAEPretrain(pl.LightningModule):
#      12     def __init__(self, config):
#
# File ~/satvision-pix4d/satvision_pix4d/optimizers/build.py:3
#       1 import torch
#       2 import logging
# ----> 3 import deepspeed
#       5 from functools import partial
#       6 from satvision_pix4d.optimizers.lamb import Lamb
#
# ModuleNotFoundError: No module named 'deepspeed'

# %%
model_filename = '/explore/nobackup/projects/pix4dcloud/jacaraba/model_development/satmae/' + \
    'satmae_satvision_pix4d_pretrain-dev/satmae_satvision_pix4d_pretrain-dev/epoch-epoch=0.ckpt/checkpoint/mp_rank_00_model_states.pt'

# %%
config_filename = '/explore/nobackup/people/jacaraba/development/satvision-pix4d/tests/configs/test_satmae_dev.yaml'

# %%
config = _C.clone()
_update_config_from_file(config, config_filename)

# %%
import os
import torch
import logging
import argparse

import warnings

warnings.filterwarnings("ignore", message=".*cuda capability 7.0.*")

from lightning.pytorch import Trainer
from lightning.pytorch.loggers import MLFlowLogger
from lightning.pytorch.callbacks import ModelCheckpoint, LearningRateMonitor

from satvision_pix4d.configs.config import _C, _update_config_from_file
from satvision_pix4d.utils import get_strategy, get_distributed_train_batches
from satvision_pix4d.pipelines import PIPELINES, get_available_pipelines
from satvision_pix4d.datamodules import DATAMODULES, get_available_datamodules


# -----------------------------------------------------------------------------
# main
# -----------------------------------------------------------------------------
def main(config, output_dir):

    logging.info('Training')

    # Save configuration path to disk
    path = os.path.join(
        output_dir,
        f"{config.TAG}.config.json"
    )

    with open(path, "w") as f:
        f.write(config.dump())

    logging.info(f"Full config saved to {path}")
    logging.info(config.dump())

    # Get the proper pipeline
    available_pipelines = get_available_pipelines()
    logging.info("Available pipelines:", available_pipelines)

    pipeline = PIPELINES[config.PIPELINE]
    logging.info(f'Using {pipeline}')

    ptlPipeline = pipeline(config)

    # Resume from checkpoint
    if config.MODEL.RESUME:
        logging.info(
            f'Attempting to resume from checkpoint {config.MODEL.RESUME}')
        ptlPipeline = pipeline.load_from_checkpoint(config.MODEL.RESUME)

    # Determine training strategy
    strategy = get_strategy(config)

    # Define core callbacks
    checkpoint_best = ModelCheckpoint(
        dirpath=output_dir,
        monitor="val_loss",
        mode="min",
        save_top_k=3,
        filename="best-{epoch}-{val_loss:.4f}",
    )
    checkpoint_periodic = ModelCheckpoint(
        dirpath=output_dir,
        every_n_epochs=1,
        save_top_k=-1,   # Save all checkpoints at the specified interval
        filename="epoch-{epoch}",
        save_last=True
    )
    lr_monitor_cb = LearningRateMonitor(logging_interval="epoch")

    # MLflow logger
    mlflow_logger = MLFlowLogger(
        experiment_name=config.TAG,
        # tracking_uri="file://" + os.path.abspath(config.OUTPUT),
        tracking_uri="file:///explore/nobackup/projects/pix4dcloud/mlruns",
        tags={
            "Model": config.MODEL.NAME,
            "Pipeline": config.PIPELINE,
            "Notes": config.DESCRIPTION if hasattr(config, "DESCRIPTION") else "",
        }
    )
    mlflow_logger.experiment.log_artifact(
        mlflow_logger.run_id,
        path
    )

    trainer = Trainer(
        accelerator=config.TRAIN.ACCELERATOR,
        devices=torch.cuda.device_count(),
        strategy=strategy,
        precision=config.PRECISION,
        max_epochs=config.TRAIN.EPOCHS,
        gradient_clip_val=1.0,
        # accumulate_grad_batches=getattr(config.TRAIN, "ACCUM_ITER", 1),  # If you have gradient accumulation
        log_every_n_steps=config.PRINT_FREQ,
        default_root_dir=output_dir,
        callbacks=[
            checkpoint_best,
            checkpoint_periodic,
            lr_monitor_cb
        ],
        logger=mlflow_logger
    )

    # limit the number of train batches for debugging
    if config.TRAIN.LIMIT_TRAIN_BATCHES:
        trainer.limit_train_batches = get_distributed_train_batches(
            config, trainer)

    # setup datamodule
    if config.DATA.DATAMODULE:
        available_datamodules = get_available_datamodules()
        logging.info(f"Available data modules: {available_datamodules}")
        datamoduleClass = DATAMODULES[config.DATAMODULE]
        datamodule = datamoduleClass(config)
        logging.info(f'Training using datamodule: {config.DATAMODULE}')
        
        trainer.fit(model=ptlPipeline, datamodule=datamodule)

        # quick test of datamodule
        #datamodule.setup(stage=None)
        #print("Train dataset size:", len(datamodule.trainset))
        #print("Validation dataset size:", len(datamodule.validset))

        #sample = datamodule.trainset[0]
        #print("Sample type:", type(sample))

        # If your dataset returns a tuple
        #if isinstance(sample, tuple):
        #    x, y = sample
        #    print("x shape:", x.shape)
        #    print("y shape:", y.shape)

    else:
        logging.info(
            'Training without datamodule, assuming data is set' +
            f' in pipeline: {ptlPipeline}')
        trainer.fit(model=ptlPipeline)

    return
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [16], line 16
#      14 from satvision_pix4d.configs.config import _C, _update_config_from_file
#      15 from satvision_pix4d.utils import get_strategy, get_distributed_train_batches
# ---> 16 from satvision_pix4d.pipelines import PIPELINES, get_available_pipelines
#      17 from satvision_pix4d.datamodules import DATAMODULES, get_available_datamodules
#      20 # -----------------------------------------------------------------------------
#      21 # main
#      22 # -----------------------------------------------------------------------------
#
# File /explore/nobackup/people/jacaraba/development/satvision-pix4d/satvision_pix4d/pipelines/__init__.py:1
# ----> 1 from satvision_pix4d.pipelines.satvision_pix4d_pretrain import SatVisionPix4DSatMAEPretrain
#       4 PIPELINES = {
#       5     'satvision_pix4d_satmae_pretrain': SatVisionPix4DSatMAEPretrain,
#       6 }
#       9 def get_available_pipelines():
#
# File /explore/nobackup/people/jacaraba/development/satvision-pix4d/satvision_pix4d/pipelines/satvision_pix4d_pretrain.py:7
#       4 import torchmetrics
#       5 import lightning.pytorch as pl
# ----> 7 from satvision_pix4d.models.encoders.mae import build_satmae_model
#       8 from satvision_pix4d.optimizers.build import build_optimizer
#      11 class SatVisionPix4DSatMAEPretrain(pl.LightningModule):
#
# File /explore/nobackup/people/jacaraba/development/satvision-pix4d/satvision_pix4d/models/encoders/mae.py:4
#       2 import torch.nn as nn
#       3 from functools import partial
# ----> 4 from satvision_pix4d.models.encoders.models_mae_temporal import \
#       5     MaskedAutoencoderViT as MaskedAutoencoderViTTemporal
#       6 from satvision_pix4d.models.utils.precision_support import FP32LayerNorm
#       8 # -----------------------------------------------------------------------------
#       9 # build_satmae_model
#      10 # -----------------------------------------------------------------------------
#
# File /explore/nobackup/people/jacaraba/development/satvision-pix4d/satvision_pix4d/models/encoders/models_mae_temporal.py:4
#       2 import torch.nn as nn
#       3 from timm.models.vision_transformer import PatchEmbed, Block
# ----> 4 from flash_attn.modules.mha import MHA
#       6 # These must be in your environment
#       7 from satvision_pix4d.models.utils.pos_embed import (
#       8     get_2d_sincos_pos_embed,
#       9     get_1d_sincos_pos_embed_from_grid_torch,
#      10 )
#
# ModuleNotFoundError: No module named 'flash_attn'

# %%
import sys
sys.path.insert(0, '/home/aliewehr/satvision-pix4d')
  
import torch
from satvision_pix4d.configs.config import _C, _update_config_from_file     
from satvision_pix4d.models.encoders.mae import build_satmae_model          
  
# 1. Load config
config_filename = '/home/aliewehr/satvision-pix4d/tests/configs/test_satmae_dev.yaml'
config = _C.clone()
_update_config_from_file(config, config_filename)
print("✅ Config loaded")
  
# 2. Build model architecture
model = build_satmae_model(config)
print(f"✅ Model built: {sum(p.numel() for p in model.parameters()):,} parameters")
  
# 3. Load checkpoint weights
model_filename ='/explore/nobackup/projects/pix4dcloud/jacaraba/model_development/satmae/satmae_satvision_pix4d_pretrain-dev/satmae_satvision_pix4d_pretrain-dev/epoch-epoch=0.ckpt/checkpoint/mp_rank_00_model_states.pt'

checkpoint = torch.load(model_filename, map_location='cpu',weights_only=False)
state_dict = checkpoint.get('module', checkpoint)
cleaned = {k.replace('model.', '', 1) if k.startswith('model.') else k: v for k, v in state_dict.items()}
missing, unexpected = model.load_state_dict(cleaned, strict=False)          
print(f"✅ Checkpoint loaded ({len(missing)} missing, {len(unexpected)} unexpected keys)")
  
# 4. Set to eval mode
model.eval()
print("✅ Model ready for inference!")
# Out:
# ✅ Config loaded
# ✅ Model built: 336,158,208 parameters
# ✅ Checkpoint loaded (128 missing, 128 unexpected keys)
# ✅ Model ready for inference!
